# %% [markdown]
# <a href="https://colab.research.google.com/github/hemantnr/probable-broccoli/blob/main/LinReg_model_Hemanth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_excel('/content/NMC_cycling_data.xlsx', skiprows = 2)

# %%
data.head()
# Out:
#   Unnamed: 0  Ambient temperature  Discharging current  Depth of discharge  \
# 0  cell_name                  NaN                  NaN                 NaN
# 1         B2                 15.0                 -2.6               100.0
# 2        NaN                 15.0                 -2.6               100.0
# 3        NaN                 15.0                 -2.6               100.0
# 4          8                 15.0                 -2.6               100.0
#
#    Average charging current  State of Health  dSOH/dNeq
# 0                       NaN              NaN        NaN
# 1                      2.05            1.000    0.00000
# 2                      2.00            0.975    0.01146
# 3                      1.93            0.950    0.02222
# 4                      1.90            0.925    0.03184

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Ambient temperature', 'Discharging current',
#        'Depth of discharge', 'Average charging current', 'State of Health',
#        'dSOH/dNeq'],
#       dtype='object')

# %%
data = data.drop(['Unnamed: 0'], axis = 1)

# %%
data.head()
# Out:
#    Ambient temperature  Discharging current  Depth of discharge  \
# 0                  NaN                  NaN                 NaN
# 1                 15.0                 -2.6               100.0
# 2                 15.0                 -2.6               100.0
# 3                 15.0                 -2.6               100.0
# 4                 15.0                 -2.6               100.0
#
#    Average charging current  State of Health  dSOH/dNeq
# 0                       NaN              NaN        NaN
# 1                      2.05            1.000    0.00000
# 2                      2.00            0.975    0.01146
# 3                      1.93            0.950    0.02222
# 4                      1.90            0.925    0.03184

# %%
data = data.dropna()
data = data.reset_index(drop = True)

# %%
data.head()
# Out:
#    Ambient temperature  Discharging current  Depth of discharge  \
# 0                 15.0                 -2.6               100.0
# 1                 15.0                 -2.6               100.0
# 2                 15.0                 -2.6               100.0
# 3                 15.0                 -2.6               100.0
# 4                 15.0                 -2.6               100.0
#
#    Average charging current  State of Health  dSOH/dNeq
# 0                      2.05            1.000    0.00000
# 1                      2.00            0.975    0.01146
# 2                      1.93            0.950    0.02222
# 3                      1.90            0.925    0.03184
# 4                      1.86            0.900    0.06180

# %%
data.shape
# Out:
# (252, 6)

# %%
# %%shell
# pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
training_data, testing_data = train_test_split(data, test_size = 0.3,random_state = 25)

# %%
training_data.head()
# Out:
#      Ambient temperature  Discharging current  Depth of discharge  \
# 107                 25.0                 -5.2               100.0
# 35                  15.0                 -5.2                50.0
# 91                  25.0                 -7.8               100.0
# 28                  15.0                 -5.2                50.0
# 105                 25.0                 -5.2               100.0
#
#      Average charging current  State of Health  dSOH/dNeq
# 107                      1.73            0.800    0.04910
# 35                       2.16            0.800    0.12200
# 91                       1.92            0.975    0.02277
# 28                       2.20            0.975    0.01150
# 105                      1.78            0.850    0.03942

# %%
training_data.shape
# Out:
# (176, 6)

# %%
testing_data.shape
# Out:
# (76, 6)

# %%
testing_data.head(20)
# Out:
#      Ambient temperature  Discharging current  Depth of discharge  \
# 153                 40.0                 -2.6               100.0
# 200                 10.0                 -2.6               100.0
# 66                  25.0                 -7.8               100.0
# 229                 25.0                 -2.6               100.0
# 224                 10.0                 -2.6                67.0
# 134                 25.0                 -5.2                16.0
# 4                   15.0                 -2.6               100.0
# 149                 40.0                 -5.2               100.0
# 97                  25.0                 -7.8               100.0
# 202                 10.0                 -2.6               100.0
# 6                   15.0                 -2.6               100.0
# 12                  15.0                 -5.2               100.0
# 148                 40.0                 -5.2               100.0
# ...

# %%
training_X = training_data[['Ambient temperature', 'Discharging current',
       'Depth of discharge', 'Average charging current', 'State of Health']]

training_Y = training_data[['dSOH/dNeq']]


testing_X = testing_data[['Ambient temperature', 'Discharging current',
       'Depth of discharge', 'Average charging current', 'State of Health']]

testing_Y = testing_data[['dSOH/dNeq']]

# %%
training_X
# Out:
#      Ambient temperature  Discharging current  Depth of discharge  \
# 107                 25.0                 -5.2               100.0
# 35                  15.0                 -5.2                50.0
# 91                  25.0                 -7.8               100.0
# 28                  15.0                 -5.2                50.0
# 105                 25.0                 -5.2               100.0
# ..                   ...                  ...                 ...
# 61                  25.0                -10.5               100.0
# 143                 40.0                 -7.8               100.0
# 218                 10.0                 -2.6                67.0
# 62                  25.0                -10.5               100.0
# 132                 25.0                 -5.2                16.0
#
#      Average charging current  State of Health
# 107                      1.73            0.800
# 35                       2.16            0.800
# ...

# %%
training_Y
# Out:
#      dSOH/dNeq
# 107   0.049100
# 35    0.122000
# 91    0.022770
# 28    0.011500
# 105   0.039420
# ..         ...
# 61    0.298100
# 143   0.064135
# 218   0.022652
# 62    0.337100
# 132   0.004411
#
# [176 rows x 1 columns]

# %%
testing_X
# Out:
#      Ambient temperature  Discharging current  Depth of discharge  \
# 153                 40.0                 -2.6               100.0
# 200                 10.0                 -2.6               100.0
# 66                  25.0                 -7.8               100.0
# 229                 25.0                 -2.6               100.0
# 224                 10.0                 -2.6                67.0
# ..                   ...                  ...                 ...
# 68                  25.0                 -7.8               100.0
# 242                 40.0                 -3.9               100.0
# 133                 25.0                 -5.2                16.0
# 78                  25.0                 -5.2               100.0
# 85                  25.0                 -2.6               100.0
#
#      Average charging current  State of Health
# 153                     2.530            1.000
# 200                     2.520            0.950
# ...

# %%
testing_Y
# Out:
#      dSOH/dNeq
# 153   0.000000
# 200   0.061800
# 66    0.022300
# 229   0.148000
# 224   0.138150
# ..         ...
# 68    0.030420
# 242   0.011891
# 133   0.004763
# 78    0.042500
# 85    0.015980
#
# [76 rows x 1 columns]

# %%
model = LinearRegression()

# %%
model.fit(training_X, training_Y)
predict_Y = model.predict(testing_X)
